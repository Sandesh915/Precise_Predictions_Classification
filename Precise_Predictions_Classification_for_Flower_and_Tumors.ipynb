# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandesh915/Precise_Predictions_Classification/blob/main/Precise_Predictions_Classification_for_Flower_and_Tumors.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
# the data set is available at the url below.
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0231EN-SkillsNetwork/datasets/iris.csv"

# using the read_csv function in the pandas library, we load the data into a dataframe.

df = pd.read_csv(URL)

# %%
df.sample(5)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 86             6.7           3.1            4.7           1.5  Iris-versicolor
# 17             5.1           3.5            1.4           0.3      Iris-setosa
# 144            6.7           3.3            5.7           2.5   Iris-virginica
# 39             5.1           3.4            1.5           0.2      Iris-setosa
# 116            6.5           3.0            5.5           1.8   Iris-virginica

# %%
df.shape
# Out:
# (150, 5)

# %%
df.Species.value_counts().plot.bar()
# Out:
# <Axes: xlabel='Species'>

# %%
target = df["Species"]
features = df[["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]]

# %%
classifier = LogisticRegression()
classifier.fit(features,target)
# Out:
# LogisticRegression()

# %%
#Higher the score, better the model.
classifier.score(features,target)
# Out:
# 0.9733333333333334

# %%
classifier.predict([[5.4,2.6,4.1,1.3]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Iris-versicolor'], dtype=object)

# %% [markdown]
# * Exercise 1 - Load a dataset
# * Exercise 2 - Identify the target column and the data columns
# * Exercise 3 - Build and Train a new classifier
# * Exercise 4 - Evaluate the model
# * Exercise 5 - Find out if a tumor is cancerous

# %%
URL2 = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-BD0231EN-SkillsNetwork/datasets/cancer.csv"
df2 = pd.read_csv(URL2)

# %%
df2.sample(5)
# Out:
#      radius_mean  perimeter_mean  area_mean  smoothness_mean  \
# 289        11.37           72.17      396.0          0.08713
# 119        17.95          114.20      982.0          0.08402
# 37         13.03           82.61      523.8          0.08983
# 418        12.70           80.88      495.0          0.08785
# 88         12.36           79.78      466.1          0.08772
#
#      compactness_mean  concavity_mean  symmetry_mean  diagnosis
# 289           0.05008         0.02399         0.2013     Benign
# 119           0.06722         0.07293         0.2129  Malignant
# 37            0.03766         0.02562         0.1467     Benign
# 418           0.05794         0.02360         0.1583     Benign
# 88            0.09445         0.06015         0.1930     Benign

# %%
df2.shape
# Out:
# (569, 8)

# %%
df2.diagnosis.value_counts().plot.bar()
# Out:
# <Axes: xlabel='diagnosis'>

# %%
target2 = df2["diagnosis"]
features2 = df2[["radius_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","symmetry_mean"]]

# %%
classifier2 = LogisticRegression()
classifier2.fit(features2,target2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
classifier2.score(features2,target2)
# Out:
# 0.8998242530755711

# %%
classifier2.predict([[13.45,86.6,555.1,0.1022,0.08165,0.03974,0.1638]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['Benign'], dtype=object)
